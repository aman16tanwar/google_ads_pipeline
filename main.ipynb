# %%
import pandas as pd

# %%
df= pd.read_csv('main.csv')

# %%
df.head()
# Out:
#   Account_Name              Data_Source_name        Date Campaign_Name  \
# 0      SkiBig3  API Feed - Amazon Ads - data  2025-07-07     2024-2025
# 1      SkiBig3  API Feed - Amazon Ads - data  2025-07-11     2024-2025
# 2      SkiBig3  API Feed - Amazon Ads - data  2025-07-10     2024-2025
# 3      SkiBig3  API Feed - Amazon Ads - data  2025-07-08     2024-2025
# 4      SkiBig3  API Feed - Amazon Ads - data  2025-07-09     2024-2025
#
#                        Channel  Objective     Audience     Promo Location  \
# 0  Amazon Prime Video Audience  Awareness  Destination  Ski Stay      USA
# 1  Amazon Prime Video Audience  Awareness  Destination  Ski Stay      USA
# 2  Amazon Prime Video Audience  Awareness  Destination  Ski Stay      USA
# 3  Amazon Prime Video Audience  Awareness  Destination  Ski Stay      USA
# 4  Amazon Prime Video Audience  Awareness  Destination  Ski Stay      USA
#
#          Ad_Name  ... Revenue Purchases  SkiBig3_Conversions  Visits  Spend  \
# ...

# %%
type(df['Data_Source_name'])
# Out:
# pandas.core.series.Series

# %%
list(df['Data_Source_name'])[0][11:20].lower().strip()
# Out:
# 'amazon ad'

# %%
df['Platform_name']=df['Data_Source_name'].str[11:20]

# %%
df.head()
# Out:
#   Account_Name              Data_Source_name        Date Campaign_Name  \
# 0      SkiBig3  API Feed - Amazon Ads - data  2025-07-07     2024-2025
# 1      SkiBig3  API Feed - Amazon Ads - data  2025-07-11     2024-2025
# 2      SkiBig3  API Feed - Amazon Ads - data  2025-07-10     2024-2025
# 3      SkiBig3  API Feed - Amazon Ads - data  2025-07-08     2024-2025
# 4      SkiBig3  API Feed - Amazon Ads - data  2025-07-09     2024-2025
#
#                        Channel  Objective     Audience     Promo Location  \
# 0  Amazon Prime Video Audience  Awareness  Destination  Ski Stay      USA
# 1  Amazon Prime Video Audience  Awareness  Destination  Ski Stay      USA
# 2  Amazon Prime Video Audience  Awareness  Destination  Ski Stay      USA
# 3  Amazon Prime Video Audience  Awareness  Destination  Ski Stay      USA
# 4  Amazon Prime Video Audience  Awareness  Destination  Ski Stay      USA
#
#          Ad_Name  ... Purchases SkiBig3_Conversions  Visits  Spend  \
# ...

# %%
df.sort_values(by=['Spend'],ascending=False)
# Out:
#     Account_Name                Data_Source_name        Date Campaign_Name  \
# 217      SkiBig3                War Room - DV360  2025-07-04     2025-2026
# 215      SkiBig3                War Room - DV360  2025-07-04     2025-2026
# 357      SkiBig3  \t SkiBig3 - Google Ads - Main  2025-07-03     2025-2026
# 365      SkiBig3  \t SkiBig3 - Google Ads - Main  2025-07-02     2025-2026
# 358      SkiBig3  \t SkiBig3 - Google Ads - Main  2025-07-04     2025-2026
# ..           ...                             ...         ...           ...
# 761      SkiBig3  \t SkiBig3 - Google Ads - Main  2025-07-09     2025-2026
# 762      SkiBig3  \t SkiBig3 - Google Ads - Main  2025-07-06     2025-2026
# 763      SkiBig3  \t SkiBig3 - Google Ads - Main  2025-07-10     2025-2026
# 764      SkiBig3  \t SkiBig3 - Google Ads - Main  2025-07-13     2025-2026
# 3        SkiBig3    API Feed - Amazon Ads - data  2025-07-08     2024-2025
#
# ...

# %%
try:
    x=1/0
except ZeroDivisionError:
    print('There is a Zero division error')
# Out:
# There is a Zero division error

# %%
with open('text.txt','w') as f:
    f.write("This is first line \n")
    f.write("This is second line \n")
    f.write("This is third line \n")

# %%
f.close()

# %%
names=['aman','ranjana','vishnu','harinder','sunita']

# %%
abc_test=[]
for name in names:
    abc_test.append(f"Name is {name}")
    print(abc_test)
# Out:
# ['Name is aman']
# ['Name is aman', 'Name is ranjana']
# ['Name is aman', 'Name is ranjana', 'Name is vishnu']
# ['Name is aman', 'Name is ranjana', 'Name is vishnu', 'Name is harinder']
# ['Name is aman', 'Name is ranjana', 'Name is vishnu', 'Name is harinder', 'Name is sunita']

# %%
abc_test=[]
for i in abc_list:
    abc_test.append(i+1)
    print(abc_test)
# Out:
# [2]
# [2, 3]
# [2, 3, 5]
# [2, 3, 5, 6]
# [2, 3, 5, 6, 7]
# [2, 3, 5, 6, 7, 8]
# [2, 3, 5, 6, 7, 8, 9]
# [2, 3, 5, 6, 7, 8, 9, 10]
# [2, 3, 5, 6, 7, 8, 9, 10, 12]

# %%
def add_number(a,b):
    return a+b

# %%
print(add_number(5,17))
# Out:
# 22

# %%
def database_columns(*args):
    for args in args:
        print(args)

# %%
database_columns("name","address","dob","city")
# Out:
# name
# address
# dob
# city

# %%
def database_columns(**kwargs):
    for value in kwargs.items():
        print(value)

# %%
print(database_columns(name="Aman",age="35"))
# Out:
# ('name', 'Aman')
# ('age', '35')
# None
